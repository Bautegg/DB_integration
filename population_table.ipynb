# %%
import pandas as pd

delimiter = "\t"
file_path = "demo_gind_tabular.tsv"
df = pd.read_csv(file_path, sep=delimiter, na_values=": ", keep_default_na=True)
pd.options.display.float_format = "{:.0f}".format
df.iloc[:, 0] = df.iloc[:, 0].replace(regex={",": "_"})

print(df)

df2 = df.iloc[:, 0].str.split("_", expand=True)
df2 = df2.iloc[:, [2,1]]
print(df2)
print(df2.iloc[:,0].unique())
print(df2.iloc[:,1].unique())
# Out:
#      freq,indic_de,geo\TIME_PERIOD   1960    1961    1962    1963    1964   \
# 0                         A_AVG_AD     NaN     NaN     NaN     NaN     NaN
# 1                         A_AVG_AL 1608800 1659800 1711319 1762621 1814135
# 2                         A_AVG_AM     NaN     NaN     NaN     NaN     NaN
# 3                         A_AVG_AT 7047539 7086299 7129864 7175811 7223801
# 4                         A_AVG_AZ     NaN     NaN     NaN     NaN     NaN
# ...                            ...     ...     ...     ...     ...     ...
# 1516                   A_POPTRT_SM     NaN     NaN     NaN     NaN     NaN
# 1517                   A_POPTRT_TR     NaN     NaN     NaN     NaN     NaN
# 1518                   A_POPTRT_UA     NaN     NaN     NaN     NaN     NaN
# 1519                   A_POPTRT_UK     NaN     NaN     NaN     NaN     NaN
# 1520                   A_POPTRT_XK     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
import json

eu_countries = {
    'AD': 'Andorra',
    'AL': 'Albania',
    'AM': 'Armenia',
    'AT': 'Austria',
    'AZ': 'Azerbaijan',
    'BA': 'Bosnia and Herzegovina',
    'BE': 'Belgium',
    'BG': 'Bulgaria',
    'BY': 'Belarus',
    'CH': 'Switzerland',
    'CY': 'Cyprus',
    'CZ': 'Czech Republic',
    'DE': 'Germany',
    'DK': 'Denmark',
    'EA19': 'Euro Area (19 countries)',
    'EA20': 'Euro Area (20 countries)',
    'EE': 'Estonia',
    'EEA31': 'European Economic Area (31 countries)',
    'EFTA': 'European Free Trade Association',
    'EL': 'Greece',
    'ES': 'Spain',
    'EU27': 'European Union (27 countries)',
    'EU28': 'European Union (28 countries)',
    'FI': 'Finland',
    'FR': 'France',
    'FX': 'Metropolitan France',
    'GE': 'Georgia',
    'HR': 'Croatia',
    'HU': 'Hungary',
    'IE': 'Ireland',
    'IS': 'Iceland',
    'IT': 'Italy',
    'LI': 'Liechtenstein',
    'LT': 'Lithuania',
    'LU': 'Luxembourg',
    'LV': 'Latvia',
    'MC': 'Monaco',
    'MD': 'Moldova',
    'ME': 'Montenegro',
    'MK': 'North Macedonia',
    'MT': 'Malta',
    'NL': 'Netherlands',
    'NO': 'Norway',
    'PL': 'Poland',
    'PT': 'Portugal',
    'RO': 'Romania',
    'RS': 'Serbia',
    'RU': 'Russia',
    'SE': 'Sweden',
    'SI': 'Slovenia',
    'SK': 'Slovakia',
    'SM': 'San Marino',
    'TR': 'Turkey',
    'UA': 'Ukraine',
    'UK': 'United Kingdom',
    'XK': 'Kosovo'
}

# country_codes = json.dumps(eu_countries)
print(country_codes)

with open("country_codes.json", "w") as outfile:
    json.dump(eu_countries, outfile)
# Out:
# {"AD": "Andorra", "AL": "Albania", "AM": "Armenia", "AT": "Austria", "AZ": "Azerbaijan", "BA": "Bosnia and Herzegovina", "BE": "Belgium", "BG": "Bulgaria", "BY": "Belarus", "CH": "Switzerland", "CY": "Cyprus", "CZ": "Czech Republic", "DE": "Germany", "DK": "Denmark", "EA19": "Euro Area (19 countries)", "EA20": "Euro Area (20 countries)", "EE": "Estonia", "EEA31": "European Economic Area (31 countries)", "EFTA": "European Free Trade Association", "EL": "Greece", "ES": "Spain", "EU27": "European Union (27 countries)", "EU28": "European Union (28 countries)", "FI": "Finland", "FR": "France", "FX": "Metropolitan France", "GE": "Georgia", "HR": "Croatia", "HU": "Hungary", "IE": "Ireland", "IS": "Iceland", "IT": "Italy", "LI": "Liechtenstein", "LT": "Lithuania", "LU": "Luxembourg", "LV": "Latvia", "MC": "Monaco", "MD": "Moldova", "ME": "Montenegro", "MK": "North Macedonia", "MT": "Malta", "NL": "Netherlands", "NO": "Norway", "PL": "Poland", "PT": "Portugal", "RO": "Romania", "RS": "Serbia"
# ...

# %%
string = """{
    'AD': 'Andorra',
    'AL': 'Albania',
    'AM': 'Armenia',
    'AT': 'Austria',
    'AZ': 'Azerbaijan',
    'BA': 'Bosnia and Herzegovina',
    'BE': 'Belgium',
    'BG': 'Bulgaria',
    'BY': 'Belarus',
    'CH': 'Switzerland',
    'CY': 'Cyprus',
    'CZ': 'Czech Republic',
    'DE': 'Germany',
    'DK': 'Denmark',
    'EA19': 'Euro Area (19 countries)',
    'EA20': 'Euro Area (20 countries)',
    'EE': 'Estonia',
    'EEA31': 'European Economic Area (31 countries)',
    'EFTA': 'European Free Trade Association',
    'EL': 'Greece',
    'ES': 'Spain',
    'EU27': 'European Union (27 countries)',
    'EU28': 'European Union (28 countries)',
    'FI': 'Finland',
    'FR': 'France',
    'FX': 'Metropolitan France',
    'GE': 'Georgia',
    'HR': 'Croatia',
    'HU': 'Hungary',
    'IE': 'Ireland',
    'IS': 'Iceland',
    'IT': 'Italy',
    'LI': 'Liechtenstein',
    'LT': 'Lithuania',
    'LU': 'Luxembourg',
    'LV': 'Latvia',
    'MC': 'Monaco',
    'MD': 'Moldova',
    'ME': 'Montenegro',
    'MK': 'North Macedonia',
    'MT': 'Malta',
    'NL': 'Netherlands',
    'NO': 'Norway',
    'PL': 'Poland',
    'PT': 'Portugal',
    'RO': 'Romania',
    'RS': 'Serbia',
    'RU': 'Russia',
    'SE': 'Sweden',
    'SI': 'Slovenia',
    'SK': 'Slovakia',
    'SM': 'San Marino',
    'TR': 'Turkey',
    'UA': 'Ukraine',
    'UK': 'United Kingdom',
    'XK': 'Kosovo'
}"""

str = string.replace("'",'"')
print(str)
# Out:
# {
#     "AD": "Andorra",
#     "AL": "Albania",
#     "AM": "Armenia",
#     "AT": "Austria",
#     "AZ": "Azerbaijan",
#     "BA": "Bosnia and Herzegovina",
#     "BE": "Belgium",
#     "BG": "Bulgaria",
#     "BY": "Belarus",
#     "CH": "Switzerland",
#     "CY": "Cyprus",
#     "CZ": "Czech Republic",
#     "DE": "Germany",
#     "DK": "Denmark",
#     "EA19": "Euro Area (19 countries)",
#     "EA20": "Euro Area (20 countries)",
#     "EE": "Estonia",
#     "EEA31": "European Economic Area (31 countries)",
#     "EFTA": "European Free Trade Association",
#     "EL": "Greece",
#     "ES": "Spain",
#     "EU27": "European Union (27 countries)",
#     "EU28": "European Union (28 countries)",
#     "FI": "Finland",
#     "FR": "France",
#     "FX": "Metropolitan France",
#     "GE": "Georgia",
#     "HR": "Croatia",
#     "HU": "Hungary",
#     "IE": "Ireland",
#     "IS": "Iceland",
#     "IT": "Italy",
#     "LI": "Liechtenstein",
#     "LT": "Lithuania",
#     "LU": "Luxembourg",
# ...
